# %%
from Bagging import create_models, create_bags, evaluate
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import pandas as pd
import random
from BaggingGA import BaggingGA

# %%
seed = 42
np.random.seed(seed)
random.seed(seed)
data = datasets.load_digits()


X = data.data
y = data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
def evaluate_bagging_ga(reps, n_trees):
    res = []
    for r in range(reps):
        bagging_ga = BaggingGA(X=X_train, y=y_train,
                           n_trees=n_trees, max_iterations=150, mutation_rate=0.5, crossover_rate=0.7, population_size=100)
        models = bagging_ga.run(X_for_test=X_test, y_for_test=y_test)
        accuracy = evaluate(X_test, y_test, models=models)
        res.append(accuracy)
    return np.mean(res), np.std(res)


def evaluate_bagging(reps, n_trees):
    res = []
    for r in range(reps):
        bags = create_bags(X_train, n_trees)
        models = create_models(X=X_train, y=y_train, bags=bags)
        accuracy = evaluate(X_test, y_test, models=models)
        res.append(accuracy)
    return np.mean(res), np.std(res)

# %%
acc_ga, acc_std_ga = evaluate_bagging_ga(reps=1, n_trees=5)
print(f"BaggingGA: {acc_ga:.2f} ± {acc_std_ga:.2f}")
# Out:
# Iteration 0, Best fitness: 0.514, Fitness: 0.514, Accuracy: 0.869
# Iteration 1, Best fitness: 0.514, Fitness: 0.498, Accuracy: 0.683
# Iteration 2, Best fitness: 0.514, Fitness: 0.507, Accuracy: 0.808
# Iteration 3, Best fitness: 0.524, Fitness: 0.524, Accuracy: 0.769
# Iteration 4, Best fitness: 0.524, Fitness: 0.519, Accuracy: 0.728
# Iteration 5, Best fitness: 0.531, Fitness: 0.531, Accuracy: 0.844
# Iteration 6, Best fitness: 0.531, Fitness: 0.512, Accuracy: 0.847
# Iteration 7, Best fitness: 0.531, Fitness: 0.523, Accuracy: 0.847
# Iteration 8, Best fitness: 0.531, Fitness: 0.507, Accuracy: 0.814
# Iteration 9, Best fitness: 0.531, Fitness: 0.514, Accuracy: 0.858
# Iteration 10, Best fitness: 0.531, Fitness: 0.505, Accuracy: 0.772
# Iteration 11, Best fitness: 0.531, Fitness: 0.517, Accuracy: 0.744
# Iteration 12, Best fitness: 0.531, Fitness: 0.507, Accuracy: 0.781
# Iteration 13, Best fitness: 0.531, Fitness: 0.510, Accuracy: 0.753
# Iteration 14, Best fitness: 0.531, Fitness: 0.521, Accuracy: 0.803
# Iteration 15, Best fitness: 0.531, Fitness: 0.530, Accuracy: 0.719
# Iteration 16, Best fitness: 0.531, Fitness: 0.528, Accuracy: 0.800
# Iteration 17, Best fitness: 0.531, Fitness: 0.514, Accuracy: 0.844
# Iteration 18, Best fitness: 0.531, Fitness: 0.521, Accuracy: 0.853
# Iteration 19, Best fitness: 0.531, Fitness: 0.516, Accuracy: 0.714
# Iteration 20, Best fitness: 0.531, Fitness: 0.526, Accuracy: 0.683
# Iteration 21, Best fitness: 0.531, Fitness: 0.531, Accuracy: 0.706
# Iteration 22, Best fitness: 0.533, Fitness: 0.533, Accuracy: 0.881
# Iteration 23, Best fitness: 0.533, Fitness: 0.516, Accuracy: 0.814
# Iteration 24, Best fitness: 0.533, Fitness: 0.521, Accuracy: 0.811
# Iteration 25, Best fitness: 0.533, Fitness: 0.528, Accuracy: 0.850
# Iteration 26, Best fitness: 0.533, Fitness: 0.521, Accuracy: 0.847
# Iteration 27, Best fitness: 0.533, Fitness: 0.519, Accuracy: 0.792
# Iteration 67, Best fitness: 0.549, Fitness: 0.524, Accuracy: 0.786
# Iteration 68, Best fitness: 0.549, Fitness: 0.509, Accuracy: 0.775
# Iteration 69, Best fitness: 0.549, Fitness: 0.519, Accuracy: 0.831
# Iteration 70, Best fitness: 0.549, Fitness: 0.524, Accuracy: 0.656
# Iteration 71, Best fitness: 0.549, Fitness: 0.517, Accuracy: 0.647
# Iteration 72, Best fitness: 0.549, Fitness: 0.533, Accuracy: 0.769
# Iteration 73, Best fitness: 0.549, Fitness: 0.549, Accuracy: 0.836
# Iteration 74, Best fitness: 0.549, Fitness: 0.530, Accuracy: 0.781
# Iteration 75, Best fitness: 0.549, Fitness: 0.528, Accuracy: 0.842
# Iteration 76, Best fitness: 0.549, Fitness: 0.521, Accuracy: 0.853
# Iteration 77, Best fitness: 0.549, Fitness: 0.530, Accuracy: 0.769
# Iteration 78, Best fitness: 0.549, Fitness: 0.542, Accuracy: 0.775
# Iteration 79, Best fitness: 0.549, Fitness: 0.535, Accuracy: 0.825
# Iteration 80, Best fitness: 0.549, Fitness: 0.521, Accuracy: 0.789
# Iteration 81, Best fitness: 0.549, Fitness: 0.528, Accuracy: 0.608
# Iteration 82, Best fitness: 0.549, Fitness: 0.528, Accuracy: 0.833
# Iteration 83, Best fitness: 0.549, Fitness: 0.521, Accuracy: 0.825
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 acc_ga, acc_std_ga = evaluate_bagging_ga(reps=1, n_trees=5)
#       2 print(f"BaggingGA: {acc_ga:.2f} ± {acc_std_ga:.2f}")
#
# Cell In[3], line 6, in evaluate_bagging_ga(reps, n_trees)
#       3 for r in range(reps):
#       4     bagging_ga = BaggingGA(X=X_train, y=y_train,
#       5                        n_trees=n_trees, max_iterations=150, mutation_rate=0.5, crossover_rate=0.7, population_size=100)
# ----> 6     models = bagging_ga.run(X_for_test=X_test, y_for_test=y_test)
#       7     accuracy = evaluate(X_test, y_test, models=models)
#       8     res.append(accuracy)
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/src/BaggingGA.py:69, in BaggingGA.run(self, X_for_test, y_for_test)
#      66 iteration = 0
#      68 while iteration < self.max_iterations:
# ---> 69     models = create_models(X_train, y_train, population)
#      70     fitness = self.calculate_fitness(models, X_test, y_test)
#      71     fitness_pointer = np.median(fitness)
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/src/Bagging.py:56, in create_models(X, y, bags)
#      55 def create_models(X, y, bags: List[Bag]) -> List[BaggingModel]:
# ---> 56     models = [create_model(X, y, bag) for bag in bags]
#      57     return models
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/src/Bagging.py:52, in create_model(X, y, bag)
#      50 X_mapped, y_mapped = bag.get_mapped_data(X, y)
#      51 model = DecisionTreeClassifier()
# ---> 52 model.fit(X_mapped, y_mapped)
#      53 return BaggingModel(model, bag)
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/sklearn/tree/_classes.py:1024, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     993 @_fit_context(prefer_skip_nested_validation=True)
#     994 def fit(self, X, y, sample_weight=None, check_input=True):
#     995     """Build a decision tree classifier from the training set (X, y).
#     996
#     997     Parameters
#    (...)   1021         Fitted estimator.
#    1022     """
# -> 1024     super()._fit(
#    1025         X,
#    1026         y,
#    1027         sample_weight=sample_weight,
#    1028         check_input=check_input,
#    1029     )
#    1030     return self
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/sklearn/tree/_classes.py:294, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     291 self.n_outputs_ = y.shape[1]
#     293 if is_classification:
# --> 294     check_classification_targets(y)
#     295     y = np.copy(y)
#     297     self.classes_ = []
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/sklearn/utils/multiclass.py:214, in check_classification_targets(y)
#     202 def check_classification_targets(y):
#     203     """Ensure that target y is of a non-regression type.
#     204
#     205     Only the following target types (as defined in type_of_target) are allowed:
#    (...)    212         Target values.
#     213     """
# --> 214     y_type = type_of_target(y, input_name="y")
#     215     if y_type not in [
#     216         "binary",
#     217         "multiclass",
#    (...)    220         "multilabel-sequences",
#     221     ]:
#     222         raise ValueError(
#     223             f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     224             "classifier, which expects discrete classes on a "
#     225             "regression target with continuous values."
#     226         )
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/sklearn/utils/multiclass.py:423, in type_of_target(y, input_name, raise_unknown)
#     421 if issparse(first_row_or_val):
#     422     first_row_or_val = first_row_or_val.data
# --> 423 if cached_unique(y).shape[0] > 2 or (y.ndim == 2 and len(first_row_or_val) > 1):
#     424     # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     425     return "multiclass" + suffix
#     426 else:
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/sklearn/utils/_unique.py:105, in cached_unique(xp, *ys)
#      81 def cached_unique(*ys, xp=None):
#      82     """Return the unique values of ys.
#      83
#      84     Use the cached values from dtype.metadata if present.
#    (...)    103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/sklearn/utils/_unique.py:105, in <genexpr>(.0)
#      81 def cached_unique(*ys, xp=None):
#      82     """Return the unique values of ys.
#      83
#      84     Use the cached values from dtype.metadata if present.
#    (...)    103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/sklearn/utils/_unique.py:78, in _cached_unique(y, xp)
#      76     pass
#      77 xp, _ = get_namespace(y, xp=xp)
# ---> 78 return xp.unique_values(y)
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/sklearn/utils/_array_api.py:416, in _NumPyAPIWrapper.unique_values(self, x)
#     415 def unique_values(self, x):
# --> 416     return numpy.unique(x)
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/numpy/lib/_arraysetops_impl.py:286, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     284 ar = np.asanyarray(ar)
#     285 if axis is None:
# --> 286     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     287                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None)
#     288     return _unpack_tuple(ret)
#     290 # axis was specified and not None
#
# File ~/HDD/Univerity/SimulatedAnnealingBagging/.venv/lib/python3.12/site-packages/numpy/lib/_arraysetops_impl.py:353, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis)
#     351     aux = ar[perm]
#     352 else:
# --> 353     ar.sort()
#     354     aux = ar
#     355 mask = np.empty(aux.shape, dtype=np.bool)
#
# KeyboardInterrupt:
